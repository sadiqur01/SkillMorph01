# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiqur01/SkillMorph01/blob/main/skillMorph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to SkillMorph")
# Out:
# Welcome to SkillMorph
